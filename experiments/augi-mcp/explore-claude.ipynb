# %%
import json
import pprint
from pathlib import Path

# Method 1: Basic JSON loading
def load_and_explore_json(file_path):
    """Load JSON file and explore its structure"""
    
    # Load the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)
    
    # Basic exploration
    print(f"File: {file_path}")
    print(f"Type: {type(data)}")
    print(f"Size: {len(data) if hasattr(data, '__len__') else 'N/A'}")
    
    return data

# Method 2: Pretty print structure
def explore_json_structure(data, max_depth=2, current_depth=0):
    """Recursively explore JSON structure"""
    
    if current_depth > max_depth:
        return "..."
    
    if isinstance(data, dict):
        result = {}
        for key, value in data.items():
            if isinstance(value, (dict, list)):
                result[key] = f"{type(value).__name__}({len(value)} items)"
            else:
                result[key] = f"{type(value).__name__}: {str(value)[:50]}..."
        return result
    
    elif isinstance(data, list):
        if len(data) == 0:
            return "Empty list"
        elif len(data) == 1:
            return [explore_json_structure(data[0], max_depth, current_depth + 1)]
        else:
            return [
                explore_json_structure(data[0], max_depth, current_depth + 1),
                f"... and {len(data) - 1} more items"
            ]
    
    else:
        return f"{type(data).__name__}: {str(data)[:50]}..."

# Example usage:
file_path = "data/conversations.json"

# Load the data
data = load_and_explore_json(file_path)

# Explore structure
print("\n=== JSON Structure ===")
structure = explore_json_structure(data)
pprint.pprint(structure, width=80, depth=3)

# If it's a list, show first few items
if isinstance(data, list):
    print(f"\n=== First item details ===")
    if len(data) > 0:
        pprint.pprint(data[0], width=80, depth=2)

# If it's a dict, show keys and sample values
elif isinstance(data, dict):
    print(f"\n=== Dictionary keys ===")
    for key, value in data.items():
        print(f"{key}: {type(value).__name__}")
        if isinstance(value, (list, dict)) and len(value) > 0:
            print(f"  Sample: {str(value)[:100]}...")
# Out:
# File: data/conversations.json
# Type: <class 'list'>
# Size: 690
#
# === JSON Structure ===
# [{'account': 'dict(1 items)',
#   'chat_messages': 'list(8 items)',
#   'created_at': 'str: 2024-05-28T13:05:48.783430Z...',
#   'name': 'str: Monetizing Creativity with Blockchain AGI...',
#   'updated_at': 'str: 2024-05-28T13:12:45.115241Z...',
#   'uuid': 'str: b4fa5efd-9e1c-4e4b-a8fe-ae1dba7ef312...'},
#  '... and 689 more items']
#
# === First item details ===
# {'account': {'uuid': '2fc29045-9a0b-488f-af46-48e235f655ea'},
#  'chat_messages': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}],
#  'created_at': '2024-05-28T13:05:48.783430Z',
#  'name': 'Monetizing Creativity with Blockchain AGI',
#  'updated_at': '2024-05-28T13:12:45.115241Z',
#  'uuid': 'b4fa5efd-9e1c-4e4b-a8fe-ae1dba7ef312'}

# %% [markdown]
# # Parse into Llamaindex document

# %%
from typing import List, Dict, Any

from llama_index.core import Document

def create_documents_per_turn(conversations_data: List[Dict]) -> List[Document]:
    """
    Create one document for each turn/message in conversations.
    
    Args:
        conversations_data: List of conversation dictionaries from JSON
        
    Returns:
        List of LlamaIndex Document objects (one per message)
    """
    docs = []
    
    for conversation in conversations_data:
        thread_id = conversation.get('uuid', 'unknown')
        conversation_name = conversation.get('name', 'Untitled Conversation')
        conversation_created = conversation.get('created_at')
        
        # Process each message as a separate document
        for turn_idx, message in enumerate(conversation.get('chat_messages', [])):
            # Extract text content from message
            text_content = ""
            content = message.get('content', [])
            
            if isinstance(content, list):
                text_parts = []
                for content_item in content:
                    if isinstance(content_item, dict) and 'text' in content_item:
                        text_parts.append(content_item['text'])
                text_content = "\n".join(text_parts)
            elif isinstance(content, str):
                text_content = content
            elif isinstance(content, dict) and 'text' in content:
                text_content = content['text']
            
            # Only create document if there's actual text content
            if text_content.strip():
                docs.append(
                    Document(
                        text=text_content,
                        metadata={
                            "thread": thread_id,
                            "thread_name": conversation_name,
                            "role": message.get('sender', 'unknown'),  # "human" / "assistant"
                            "turn_index": turn_idx,
                            "conversation_created": conversation_created,
                            "message_created": message.get('created_at'),
                            "source": "conversations.json"
                        }
                    )
                )
    
    print(f"Created {len(docs)} documents from individual turns")
    return docs

# Create documents - one per turn/message
docs = create_documents_per_turn(data)

# Show statistics
if docs:
    print(f"\nDocument Statistics:")
    print(f"Total documents: {len(docs)}")
    
    # Count by role
    role_counts = {}
    for doc in docs:
        role = doc.metadata.get('role', 'unknown')
        role_counts[role] = role_counts.get(role, 0) + 1
    
    print(f"Messages by role: {role_counts}")
    
    # Show sample document
    print(f"\nSample document:")
    sample_doc = docs[0]
    print(f"Role: {sample_doc.metadata['role']}")
    print(f"Thread: {sample_doc.metadata['thread_name']}")
    print(f"Text length: {len(sample_doc.text)}")
    print(f"Text preview: {sample_doc.text[:200]}...")
    print(f"Full metadata: {sample_doc.metadata}")
# Out:
# Created 11284 documents from individual turns
#
# Document Statistics:
# Total documents: 11284
# Messages by role: {'human': 5655, 'assistant': 5629}
#
# Sample document:
# Role: human
# Thread: Monetizing Creativity with Blockchain AGI
# Text length: 215
# Text preview: Right now can I scope this down or pick a single focused that’s in this area I can turn into a Soloprenuer or small startup.
#
# I was thinking exploring LLms for writers and using ai to define and own a...
# Full metadata: {'thread': 'b4fa5efd-9e1c-4e4b-a8fe-ae1dba7ef312', 'thread_name': 'Monetizing Creativity with Blockchain AGI', 'role': 'human', 'turn_index': 0, 'conversation_created': '2024-05-28T13:05:48.783430Z', 'message_created': '2024-05-28T13:07:32.757438Z', 'source': 'conversations.json'}

# %%
data[0]
# Out:
# {'uuid': 'b4fa5efd-9e1c-4e4b-a8fe-ae1dba7ef312',
#  'name': 'Monetizing Creativity with Blockchain AGI',
#  'created_at': '2024-05-28T13:05:48.783430Z',
#  'updated_at': '2024-05-28T13:12:45.115241Z',
#  'account': {'uuid': '2fc29045-9a0b-488f-af46-48e235f655ea'},
#  'chat_messages': [{'uuid': 'b458f43f-95cb-4805-83b7-7266f04103ef',
#    'text': 'Right now can I scope this down or pick a single focused that’s in this area I can turn into a Soloprenuer or small startup.\n\nI was thinking exploring LLms for writers and using ai to define and own a writing niche.',
#    'content': [{'start_timestamp': '2024-05-28T13:07:32.757438Z',
#      'stop_timestamp': '2024-05-28T13:07:32.757438Z',
#      'type': 'text',
#      'text': 'Right now can I scope this down or pick a single focused that’s in this area I can turn into a Soloprenuer or small startup.\n\nI was thinking exploring LLms for writers and using ai to define and own a writing niche.',
#      'citations': []}],
#    'sender': 'human',
#    'created_at': '2024-05-28T13:07:32.757438Z',
#    'updated_at': '2024-05-28T13:07:32.757438Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': 'bb6b0d1c-fbd2-446f-92ec-23589ce25ac5',
#    'text': 'I had a big idea to build an AGI on the Blockchain that monetizes creators and incentivizes original thinking.\n\nI have little idea how to do this and I feel like I sound crazy for proposing it',
#    'content': [{'start_timestamp': '2024-05-28T13:06:00.009748Z',
#      'stop_timestamp': '2024-05-28T13:06:00.009748Z',
#      'type': 'text',
#      'text': 'I had a big idea to build an AGI on the Blockchain that monetizes creators and incentivizes original thinking.\n\nI have little idea how to do this and I feel like I sound crazy for proposing it',
#      'citations': []}],
#    'sender': 'human',
#    'created_at': '2024-05-28T13:06:00.009748Z',
#    'updated_at': '2024-05-28T13:06:00.009748Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': 'dacf1641-ec44-4787-9c28-cfca71890f4a',
#    'text': ' Building an AGI (Artificial General Intelligence) system that is decentralized and operates on a blockchain is an ambitious and complex endeavor. While the idea of incentivizing creators and original thinking through a blockchain-based system is intriguing, there are significant technical and conceptual challenges that would need to be addressed.\n\nHere are a few points to consider:\n\n1. Defining and measuring "original thinking": One of the key challenges would be to define and quantify what constitutes "original thinking" in a way that can be objectively measured and rewarded by the system. This is a non-trivial task, as originality and creativity are subjective concepts that may vary across domains and contexts.\n\n2. Scalability and performance: Blockchain systems, by their nature, are designed for decentralized consensus and have inherent limitations in terms of transaction throughput and scalability. Running an AGI system, which typically involves large-scale data processing and computationally intensive tasks, on a blockchain could pose significant performance challenges.\n\n3. Data storage and access: AGI systems often require access to vast amounts of data for training and knowledge acquisition. Storing and accessing this data in a decentralized manner on a blockchain could be challenging, especially when dealing with large datasets or real-time data streams.\n\n4. Incentive mechanisms: Designing effective incentive mechanisms that encourage creators to contribute their original ideas and reward them fairly is a complex problem. It would involve considerations such as token economics, governance models, and mechanisms to prevent gaming or exploitation of the system.\n\n5. Privacy and security: AGI systems often deal with sensitive data and personal information. Ensuring privacy and security on a public blockchain, where all transactions are visible, could be a significant challenge.\n\nWhile the idea is intriguing, it would require substantial research and development efforts to address these and other challenges. It may be helpful to start with a more focused and incremental approach, such as exploring blockchain-based incentive mechanisms for specific domains or tasks related to creativity and innovation, rather than attempting to build a full-fledged AGI system on a blockchain from the outset.\n\nCollaborating with experts in the fields of blockchain technology, artificial intelligence, cryptoeconomics, and incentive design could help refine the idea and develop a more concrete and feasible roadmap.',
#    'content': [{'start_timestamp': '2024-05-28T13:06:00.009748Z',
#      'stop_timestamp': '2024-05-28T13:06:00.009748Z',
#      'type': 'text',
#      'text': ' Building an AGI (Artificial General Intelligence) system that is decentralized and operates on a blockchain is an ambitious and complex endeavor. While the idea of incentivizing creators and original thinking through a blockchain-based system is intriguing, there are significant technical and conceptual challenges that would need to be addressed.\n\nHere are a few points to consider:\n\n1. Defining and measuring "original thinking": One of the key challenges would be to define and quantify what constitutes "original thinking" in a way that can be objectively measured and rewarded by the system. This is a non-trivial task, as originality and creativity are subjective concepts that may vary across domains and contexts.\n\n2. Scalability and performance: Blockchain systems, by their nature, are designed for decentralized consensus and have inherent limitations in terms of transaction throughput and scalability. Running an AGI system, which typically involves large-scale data processing and computationally intensive tasks, on a blockchain could pose significant performance challenges.\n\n3. Data storage and access: AGI systems often require access to vast amounts of data for training and knowledge acquisition. Storing and accessing this data in a decentralized manner on a blockchain could be challenging, especially when dealing with large datasets or real-time data streams.\n\n4. Incentive mechanisms: Designing effective incentive mechanisms that encourage creators to contribute their original ideas and reward them fairly is a complex problem. It would involve considerations such as token economics, governance models, and mechanisms to prevent gaming or exploitation of the system.\n\n5. Privacy and security: AGI systems often deal with sensitive data and personal information. Ensuring privacy and security on a public blockchain, where all transactions are visible, could be a significant challenge.\n\nWhile the idea is intriguing, it would require substantial research and development efforts to address these and other challenges. It may be helpful to start with a more focused and incremental approach, such as exploring blockchain-based incentive mechanisms for specific domains or tasks related to creativity and innovation, rather than attempting to build a full-fledged AGI system on a blockchain from the outset.\n\nCollaborating with experts in the fields of blockchain technology, artificial intelligence, cryptoeconomics, and incentive design could help refine the idea and develop a more concrete and feasible roadmap.',
#      'citations': []}],
#    'sender': 'assistant',
#    'created_at': '2024-05-28T13:06:00.009748Z',
#    'updated_at': '2024-05-28T13:06:00.009748Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': '089eaf19-8d47-495d-99bf-9348e03449b8',
#    'text': ' Focusing on using large language models (LLMs) and AI to assist writers and help define and monetize specific writing niches could be a viable path to explore as a solopreneur or small startup. Here are some potential ideas and approaches you could consider:\n\n1. AI-assisted writing tools and platforms:\n   - Develop a writing platform that leverages LLMs to provide real-time assistance, such as content ideation, outlining, research, and editing suggestions.\n   - Offer personalized writing coaching and feedback powered by AI, tailored to specific writing genres or styles.\n   - Create a subscription-based service that provides access to AI-generated content ideas, prompts, and writing resources for various niches.\n\n2. Niche-specific content generation and curation:\n   - Identify a specific writing niche with high demand, such as technical writing, creative fiction, or content marketing.\n   - Train or fine-tune an LLM on data specific to that niche to generate high-quality, niche-relevant content.\n   - Offer content creation services or sell AI-generated content to writers, publishers, or businesses in that niche.\n   - Curate and organize niche-specific writing resources, prompts, and examples, leveraging AI to enhance discoverability and relevance.\n\n3. AI-powered writing analytics and optimization:\n   - Develop tools that use natural language processing (NLP) and AI to analyze writing samples and provide insights on style, tone, readability, and audience resonance.\n   - Offer optimization services to help writers improve their work based on AI-driven analysis and recommendations.\n   - Create a platform where writers can submit their work for AI-powered analysis and get personalized feedback and suggestions for improvement.\n\n4. AI-driven writing marketplaces:\n   - Build an online marketplace that connects writers with clients or publishers seeking niche-specific content.\n   - Use AI to match writers with projects based on their expertise, writing style, and niche focus.\n   - Implement AI-powered quality control and content evaluation to ensure high standards for the marketplace.\n\nThese are just a few examples, and you could combine or modify these ideas based on your specific interests, skills, and target market. The key would be to identify a specific writing niche or set of niches, understand the needs and pain points of writers in those areas, and leverage AI and LLMs to provide valuable solutions.\n\nStarting with a well-defined niche and a minimum viable product (MVP) could help you validate the idea, gather user feedback, and iteratively improve your offering. Additionally, building a strong community of writers and leveraging their insights could be invaluable in refining your AI-powered writing tools and services.',
#    'content': [{'start_timestamp': '2024-05-28T13:07:32.757438Z',
#      'stop_timestamp': '2024-05-28T13:07:32.757438Z',
#      'type': 'text',
#      'text': ' Focusing on using large language models (LLMs) and AI to assist writers and help define and monetize specific writing niches could be a viable path to explore as a solopreneur or small startup. Here are some potential ideas and approaches you could consider:\n\n1. AI-assisted writing tools and platforms:\n   - Develop a writing platform that leverages LLMs to provide real-time assistance, such as content ideation, outlining, research, and editing suggestions.\n   - Offer personalized writing coaching and feedback powered by AI, tailored to specific writing genres or styles.\n   - Create a subscription-based service that provides access to AI-generated content ideas, prompts, and writing resources for various niches.\n\n2. Niche-specific content generation and curation:\n   - Identify a specific writing niche with high demand, such as technical writing, creative fiction, or content marketing.\n   - Train or fine-tune an LLM on data specific to that niche to generate high-quality, niche-relevant content.\n   - Offer content creation services or sell AI-generated content to writers, publishers, or businesses in that niche.\n   - Curate and organize niche-specific writing resources, prompts, and examples, leveraging AI to enhance discoverability and relevance.\n\n3. AI-powered writing analytics and optimization:\n   - Develop tools that use natural language processing (NLP) and AI to analyze writing samples and provide insights on style, tone, readability, and audience resonance.\n   - Offer optimization services to help writers improve their work based on AI-driven analysis and recommendations.\n   - Create a platform where writers can submit their work for AI-powered analysis and get personalized feedback and suggestions for improvement.\n\n4. AI-driven writing marketplaces:\n   - Build an online marketplace that connects writers with clients or publishers seeking niche-specific content.\n   - Use AI to match writers with projects based on their expertise, writing style, and niche focus.\n   - Implement AI-powered quality control and content evaluation to ensure high standards for the marketplace.\n\nThese are just a few examples, and you could combine or modify these ideas based on your specific interests, skills, and target market. The key would be to identify a specific writing niche or set of niches, understand the needs and pain points of writers in those areas, and leverage AI and LLMs to provide valuable solutions.\n\nStarting with a well-defined niche and a minimum viable product (MVP) could help you validate the idea, gather user feedback, and iteratively improve your offering. Additionally, building a strong community of writers and leveraging their insights could be invaluable in refining your AI-powered writing tools and services.',
#      'citations': []}],
#    'sender': 'assistant',
#    'created_at': '2024-05-28T13:07:32.757438Z',
#    'updated_at': '2024-05-28T13:07:32.757438Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': 'b6aa0d04-9614-4192-885e-3276eb8d8e47',
#    'text': 'I have a lot of ideas I want to work on. But I have financial obligations.  In three months what’s the fastest way I can start making income online like 10k or more as a solo engineer?\n\n\nSomething like ai to monetize that niche or chrome extensions',
#    'content': [{'start_timestamp': '2024-05-28T13:11:21.515193Z',
#      'stop_timestamp': '2024-05-28T13:11:21.515193Z',
#      'type': 'text',
#      'text': 'I have a lot of ideas I want to work on. But I have financial obligations.  In three months what’s the fastest way I can start making income online like 10k or more as a solo engineer?\n\n\nSomething like ai to monetize that niche or chrome extensions',
#      'citations': []}],
#    'sender': 'human',
#    'created_at': '2024-05-28T13:11:21.515193Z',
#    'updated_at': '2024-05-28T13:11:21.515193Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': 'ae93dfb3-d367-44b2-ae26-10879dbac659',
#    'text': " If your primary goal is to start generating income online within three months as a solo engineer, there are a few paths you could explore. Here are some potential options:\n\n1. Freelancing and Consulting:\n   - Build a portfolio showcasing your skills in areas like web development, mobile app development, AI/ML, or any other relevant technical expertise.\n   - Sign up on freelancing platforms like Upwork, Freelancer, or Toptal, and actively bid on projects that match your skillset.\n   - Leverage your network and online presence to find consulting gigs related to your areas of expertise.\n   - Offer services like website development, application development, data analysis, or technical consulting.\n\n2. AI-powered Chrome Extensions or Browser Add-ons:\n   - Identify a specific problem or pain point that can be solved with a browser extension or add-on.\n   - Develop a useful AI-powered extension, such as a writing assistant, research tool, productivity enhancer, or content summarizer.\n   - Publish the extension on the Chrome Web Store or other browser add-on marketplaces.\n   - Monetize through premium features, subscriptions, or targeted advertising within the extension.\n\n3. AI-powered Tools or SaaS Products:\n   - Develop a niche-specific AI-powered tool or software-as-a-service (SaaS) product that addresses a specific need or problem in a particular industry or domain.\n   - Examples could include AI-powered writing assistants, content optimization tools, data analysis platforms, or personalized recommendation engines.\n   - Offer free trials or freemium plans to attract users, and then monetize through paid subscriptions or premium features.\n\n4. Online Courses or Tutorials:\n   - Leverage your expertise in specific technologies or domains by creating online courses or tutorials.\n   - Platforms like Udemy, Skillshare, or Coursera allow you to publish and sell courses on various topics.\n   - Focus on in-demand skills, such as AI/ML, web development, mobile app development, or specific programming languages.\n\n5. AI-powered Content Creation or Monetization:\n   - Develop AI models or tools that can generate high-quality content in specific niches, such as articles, stories, scripts, or marketing copy.\n   - Offer content creation services or licenses for the generated content to businesses, publishers, or creators.\n   - Explore options like selling AI-generated art, music, or other creative works.\n\nThe key to success in any of these paths is to identify a specific niche or problem that you can solve effectively with your skills and expertise. It's also essential to have a solid marketing and promotion strategy to reach potential customers or clients.\n\nWhile generating $10,000 or more as a solo engineer within three months is ambitious, it's certainly possible with dedication, hard work, and a well-executed strategy. However, it's important to manage your expectations and be prepared to adjust your approach based on the market response and feedback from potential customers.",
#    'content': [{'start_timestamp': '2024-05-28T13:11:21.515193Z',
#      'stop_timestamp': '2024-05-28T13:11:21.515193Z',
#      'type': 'text',
#      'text': " If your primary goal is to start generating income online within three months as a solo engineer, there are a few paths you could explore. Here are some potential options:\n\n1. Freelancing and Consulting:\n   - Build a portfolio showcasing your skills in areas like web development, mobile app development, AI/ML, or any other relevant technical expertise.\n   - Sign up on freelancing platforms like Upwork, Freelancer, or Toptal, and actively bid on projects that match your skillset.\n   - Leverage your network and online presence to find consulting gigs related to your areas of expertise.\n   - Offer services like website development, application development, data analysis, or technical consulting.\n\n2. AI-powered Chrome Extensions or Browser Add-ons:\n   - Identify a specific problem or pain point that can be solved with a browser extension or add-on.\n   - Develop a useful AI-powered extension, such as a writing assistant, research tool, productivity enhancer, or content summarizer.\n   - Publish the extension on the Chrome Web Store or other browser add-on marketplaces.\n   - Monetize through premium features, subscriptions, or targeted advertising within the extension.\n\n3. AI-powered Tools or SaaS Products:\n   - Develop a niche-specific AI-powered tool or software-as-a-service (SaaS) product that addresses a specific need or problem in a particular industry or domain.\n   - Examples could include AI-powered writing assistants, content optimization tools, data analysis platforms, or personalized recommendation engines.\n   - Offer free trials or freemium plans to attract users, and then monetize through paid subscriptions or premium features.\n\n4. Online Courses or Tutorials:\n   - Leverage your expertise in specific technologies or domains by creating online courses or tutorials.\n   - Platforms like Udemy, Skillshare, or Coursera allow you to publish and sell courses on various topics.\n   - Focus on in-demand skills, such as AI/ML, web development, mobile app development, or specific programming languages.\n\n5. AI-powered Content Creation or Monetization:\n   - Develop AI models or tools that can generate high-quality content in specific niches, such as articles, stories, scripts, or marketing copy.\n   - Offer content creation services or licenses for the generated content to businesses, publishers, or creators.\n   - Explore options like selling AI-generated art, music, or other creative works.\n\nThe key to success in any of these paths is to identify a specific niche or problem that you can solve effectively with your skills and expertise. It's also essential to have a solid marketing and promotion strategy to reach potential customers or clients.\n\nWhile generating $10,000 or more as a solo engineer within three months is ambitious, it's certainly possible with dedication, hard work, and a well-executed strategy. However, it's important to manage your expectations and be prepared to adjust your approach based on the market response and feedback from potential customers.",
#      'citations': []}],
#    'sender': 'assistant',
#    'created_at': '2024-05-28T13:11:21.515193Z',
#    'updated_at': '2024-05-28T13:11:21.515193Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': '633967c4-66ee-48a5-9657-b756409be2a0',
#    'text': 'How can I find a problem or niche in markets?  Like how can I see what chrome extensions people need',
#    'content': [{'start_timestamp': '2024-05-28T13:12:45.115241Z',
#      'stop_timestamp': '2024-05-28T13:12:45.115241Z',
#      'type': 'text',
#      'text': 'How can I find a problem or niche in markets?  Like how can I see what chrome extensions people need',
#      'citations': []}],
#    'sender': 'human',
#    'created_at': '2024-05-28T13:12:45.115241Z',
#    'updated_at': '2024-05-28T13:12:45.115241Z',
#    'attachments': [],
#    'files': []},
#   {'uuid': '45587ca4-4920-45d2-aee0-d626b12b38a2',
#    'text': " Finding a problem or niche in the market for a potential Chrome extension or other product can be a challenging but crucial step. Here are some methods you can use to identify market needs and opportunities:\n\n1. Analyze online communities and forums:\n   - Search for relevant online communities, forums, and social media groups related to your target audience or industry.\n   - Observe the discussions, questions, and pain points that users frequently mention.\n   - Look for recurring problems, inefficiencies, or tasks that could potentially be solved or streamlined with a Chrome extension or tool.\n\n2. Conduct user interviews and surveys:\n   - Reach out to potential users or customers in your target market and ask for their feedback and insights.\n   - Conduct interviews or surveys to understand their workflows, challenges, and areas where they would appreciate additional tools or automation.\n   - Pay attention to the language they use to describe their problems, as it can help you frame your solution in a way that resonates with them.\n\n3. Analyze search engine data:\n   - Use tools like Google Trends, KeywordTool.io, or Ahrefs to identify popular search queries and topics related to your target market.\n   - Look for queries that indicate a need, problem, or desire for a specific solution.\n   - Analyze the competition and identify gaps or areas where existing solutions fall short.\n\n4. Review product reviews and feedback:\n   - Explore review sites, app stores, and product forums related to your target market or industry.\n   - Look for common complaints, missing features, or areas where users express dissatisfaction with existing products or solutions.\n   - Identify opportunities to improve upon existing offerings or address unmet needs.\n\n5. Leverage your own experience and expertise:\n   - Draw upon your personal experiences, frustrations, or inefficiencies in your work or daily life.\n   - Identify tasks or processes that could be streamlined or automated with the right tool or extension.\n   - Validate your ideas by discussing them with others in your network or target audience.\n\n6. Attend industry events or conferences:\n   - Participate in relevant conferences, meetups, or industry events related to your target market.\n   - Network with potential users or customers and gather insights into their challenges and pain points.\n   - Observe presentations or discussions that highlight emerging trends or unmet needs in the market.\n\nOnce you have identified potential problems or niches, it's essential to validate your ideas through further research, prototyping, and user testing. This iterative process will help you refine your solution and ensure that you're addressing a genuine market need effectively.\n\nRemember, successful products or services often solve real problems for their target audience, so taking the time to understand and validate the market need is crucial before investing significant resources into development.",
#    'content': [{'start_timestamp': '2024-05-28T13:12:45.115241Z',
#      'stop_timestamp': '2024-05-28T13:12:45.115241Z',
#      'type': 'text',
#      'text': " Finding a problem or niche in the market for a potential Chrome extension or other product can be a challenging but crucial step. Here are some methods you can use to identify market needs and opportunities:\n\n1. Analyze online communities and forums:\n   - Search for relevant online communities, forums, and social media groups related to your target audience or industry.\n   - Observe the discussions, questions, and pain points that users frequently mention.\n   - Look for recurring problems, inefficiencies, or tasks that could potentially be solved or streamlined with a Chrome extension or tool.\n\n2. Conduct user interviews and surveys:\n   - Reach out to potential users or customers in your target market and ask for their feedback and insights.\n   - Conduct interviews or surveys to understand their workflows, challenges, and areas where they would appreciate additional tools or automation.\n   - Pay attention to the language they use to describe their problems, as it can help you frame your solution in a way that resonates with them.\n\n3. Analyze search engine data:\n   - Use tools like Google Trends, KeywordTool.io, or Ahrefs to identify popular search queries and topics related to your target market.\n   - Look for queries that indicate a need, problem, or desire for a specific solution.\n   - Analyze the competition and identify gaps or areas where existing solutions fall short.\n\n4. Review product reviews and feedback:\n   - Explore review sites, app stores, and product forums related to your target market or industry.\n   - Look for common complaints, missing features, or areas where users express dissatisfaction with existing products or solutions.\n   - Identify opportunities to improve upon existing offerings or address unmet needs.\n\n5. Leverage your own experience and expertise:\n   - Draw upon your personal experiences, frustrations, or inefficiencies in your work or daily life.\n   - Identify tasks or processes that could be streamlined or automated with the right tool or extension.\n   - Validate your ideas by discussing them with others in your network or target audience.\n\n6. Attend industry events or conferences:\n   - Participate in relevant conferences, meetups, or industry events related to your target market.\n   - Network with potential users or customers and gather insights into their challenges and pain points.\n   - Observe presentations or discussions that highlight emerging trends or unmet needs in the market.\n\nOnce you have identified potential problems or niches, it's essential to validate your ideas through further research, prototyping, and user testing. This iterative process will help you refine your solution and ensure that you're addressing a genuine market need effectively.\n\nRemember, successful products or services often solve real problems for their target audience, so taking the time to understand and validate the market need is crucial before investing significant resources into development.",
#      'citations': []}],
#    'sender': 'assistant',
#    'created_at': '2024-05-28T13:12:45.115241Z',
#    'updated_at': '2024-05-28T13:12:45.115241Z',
#    'attachments': [],
#    'files': []}]}

# %%
docs[0]
# Out:
# Document(id_='200033be-6255-4d84-ba83-25fb9634fd46', embedding=None, metadata={'thread': 'b4fa5efd-9e1c-4e4b-a8fe-ae1dba7ef312', 'thread_name': 'Monetizing Creativity with Blockchain AGI', 'role': 'human', 'turn_index': 0, 'conversation_created': '2024-05-28T13:05:48.783430Z', 'message_created': '2024-05-28T13:07:32.757438Z', 'source': 'conversations.json'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Right now can I scope this down or pick a single focused that’s in this area I can turn into a Soloprenuer or small startup.\n\nI was thinking exploring LLms for writers and using ai to define and own a writing niche.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %% [markdown]
# # Embed and store in DuckDB

# %%
import duckdb, datetime, uuid


db = duckdb.connect("augmcp_v0.duckdb")
db.execute("""
CREATE TABLE IF NOT EXISTS raw_chunks(
  chunk_id  TEXT PRIMARY KEY,
  thread    TEXT,
  role      TEXT,
  ts_ingest TIMESTAMP,
  content   TEXT,
  embedding DOUBLE[]
)
""")

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from tqdm import tqdm

from dotenv import load_dotenv
load_dotenv("/Users/chris/repos/openaugi/keys.env")

embedder = OpenAIEmbedding(model="text-embedding-3-small")

for d in tqdm(docs):
    emb = embedder.get_text_embedding(d.text)
    db.execute(
        "INSERT INTO raw_chunks VALUES (?,?,?,?,?,?)",
        [str(uuid.uuid4()),
         d.metadata["thread"],
         d.metadata["role"],
         datetime.datetime.fromisoformat(d.metadata["message_created"]),
         d.text,
         emb]
    )
# Out:
#   8%|▊         | 857/11284 [03:33<1:21:33,  2.13it/s]
